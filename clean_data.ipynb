# %%
import pandas as pd
# plotting
import matplotlib.pyplot as plt
import seaborn as sns
# create interactive plots
import plotly.express as px 
# numeric calculations
import numpy as np

# %%
data = pd.read_table("flickr_dataset.csv", sep=",")
# show first 5 rows of the dataframe
data.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_19116\2779211312.py:1: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_table("flickr_dataset.csv", sep=",")
#            id          user        lat      long  \
# 0  4395181099  30624617@N03  45.754858  4.821710
# 1  4394748717  35853470@N00  45.753270  4.862953
# 2  4394694699  11817998@N05  45.760655  4.846564
# 3  4394803790  11545749@N06  45.784000  4.874072
# 4  4394803554  11545749@N06  45.784000  4.874072
#
#                                                 tags  \
# 0                 chair,lyon,rhône,chaise,rhônealpes
# 1                                                NaN
# 2                                         365,iphone
# 3       nin,nineinchnails,gift,screening,toiou,avott
# 4  lyon,nin,nineinchnails,gift,screening,toiou,avott
#
#                          title   date_taken_minute   date_taken_hour  \
# ...

# %%
len(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420240 entries, 0 to 420239
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   420240 non-null  int64
#  1    user                420240 non-null  object
#  2    lat                 420240 non-null  float64
#  3    long                420240 non-null  float64
#  4    tags                316730 non-null  object
#  5    title               381911 non-null  object
#  6    date_taken_minute   420239 non-null  float64
#  7    date_taken_hour     420240 non-null  int64
#  8    date_taken_day      420240 non-null  int64
#  9    date_taken_month    420240 non-null  int64
#  10   date_taken_year     420240 non-null  int64
#  11   date_upload_minute  420228 non-null  object
#  12   date_upload_hour    420238 non-null  object
#  13   date_upload_day     420238 non-null  float64
#  14   date_upload_month   420240 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# id                          0
#  user                       0
#  lat                        0
#  long                       0
#  tags                  103510
#  title                  38329
#  date_taken_minute          1
#  date_taken_hour            0
#  date_taken_day             0
#  date_taken_month           0
#  date_taken_year            0
#  date_upload_minute        12
#  date_upload_hour           2
#  date_upload_day            2
#  date_upload_month          0
#  date_upload_year           1
# Unnamed: 16            420098
# Unnamed: 17            420240
# Unnamed: 18            420238
# dtype: int64

# %%
# Check missing values only in relevant columns (excluding Unnamed)
relevant_cols = data.columns[:16]  # First 16 columns
missing_values_relevant = data[data[relevant_cols].isna().any(axis=1)]
print(f"Total rows: {len(data)}")
print(f"Rows with missing values in relevant columns: {len(missing_values_relevant)}")
print(f"Rows with missing values in any column: {len(missing_values)}")

# Sum of missing values per relevant column
print("\nMissing values per relevant column:")
print(data[relevant_cols].isna().sum())
# Out:
# Total rows: 420240
# Rows with missing values in relevant columns: 118263
# Rows with missing values in any column: 420240
#
# Missing values per relevant column:
# id                          0
#  user                       0
#  lat                        0
#  long                       0
#  tags                  103510
#  title                  38329
#  date_taken_minute          1
#  date_taken_hour            0
#  date_taken_day             0
#  date_taken_month           0
#  date_taken_year            0
#  date_upload_minute        12
#  date_upload_hour           2
#  date_upload_day            2
#  date_upload_month          0
#  date_upload_year           1
# dtype: int64

# %%
data[relevant_cols].to_csv('data_cleaned.csv', index=False)
